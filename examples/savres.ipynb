# %%
import pandas as pd
from statsmodels.stats.weightstats import DescrStatsW
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
scf_data = pd.read_stata("../src/fedsurvey/scf/data/scf_processed.dta")

scf_data = scf_data[scf_data["age"] >= 71]

# %%
scf_data["age"].unique()
# Out:
# array([75, 89, 71, 77, 79, 73, 80, 78, 76, 81, 82, 72, 85, 74, 83, 84, 87,
#        90, 86, 88, 91, 95, 92, 93, 94], dtype=int8)

# %%
def weighted_mean(data, var, weights):
    stats = DescrStatsW(data[var], weights=data[weights])
    return stats.mean


def to_percent(y, position):
    return f"{100 * y:.2f}%"


formatter = FuncFormatter(to_percent)

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres1", "wgt"
).unstack().plot()
plt.title("Reason for saving: can't save")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/1201100060.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres2", "wgt"
).unstack().plot()
plt.title("Reason for saving: education")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/2384399675.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres3", "wgt"
).unstack().plot()
plt.title("Reason for saving: family")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/2346591443.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres4", "wgt"
).unstack().plot()
plt.title("Reason for saving: home")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/173237029.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres5", "wgt"
).unstack().plot()
plt.title("Reason for saving: purchases")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/3279881744.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres6", "wgt"
).unstack().plot()
plt.title("Reason for saving: retirement")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/2315203495.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres7", "wgt"
).unstack().plot()
plt.title("Reason for saving: liquidity/the future")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/992497806.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres8", "wgt"
).unstack().plot()
plt.title("Reason for saving: investment")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/2742888852.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres9", "wgt"
).unstack().plot()
plt.title("Reason for saving: no particular reason")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_117568/3958459272.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres3", "wgt")  # family
# Out:
# /tmp/ipykernel_117568/3619901087.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres3", "wgt")  # family
# edcl_lbl
# Bachelors degree or higher       0.060152
# high school diploma or GED       0.079107
# no high school diploma/GED       0.048913
# some college or Assoc. degree    0.065740
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(
    weighted_mean, "savres6", "wgt")  # retirement
# Out:
# /tmp/ipykernel_117568/3313085655.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres6", "wgt")  # retirement
# edcl_lbl
# Bachelors degree or higher       0.267757
# high school diploma or GED       0.230410
# no high school diploma/GED       0.193955
# some college or Assoc. degree    0.216707
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(
    weighted_mean, "savres7", "wgt")  # the future
# Out:
# /tmp/ipykernel_117568/921483200.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres7", "wgt")  # the future
# edcl_lbl
# Bachelors degree or higher       0.408016
# high school diploma or GED       0.407952
# no high school diploma/GED       0.401725
# some college or Assoc. degree    0.442544
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(
    weighted_mean, "savres5", "wgt")  # purchases
# Out:
# /tmp/ipykernel_117568/976294478.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres5", "wgt")  # purchases
# edcl_lbl
# Bachelors degree or higher       0.128907
# high school diploma or GED       0.139809
# no high school diploma/GED       0.163568
# some college or Assoc. degree    0.141283
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(
    weighted_mean, "savres1", "wgt")  # can't save
# Out:
# /tmp/ipykernel_117568/2717839900.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres1", "wgt")  # can't save
# edcl_lbl
# Bachelors degree or higher       0.059244
# high school diploma or GED       0.073690
# no high school diploma/GED       0.134277
# some college or Assoc. degree    0.057387
# dtype: float64
