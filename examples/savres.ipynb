# %%
import pandas as pd
from statsmodels.stats.weightstats import DescrStatsW
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats.mstats import winsorize
import matplotlib.pyplot as plt
from matplotlib.ticker import FuncFormatter

# %%
scf_data = pd.read_stata("../src/fedsurvey/scf/data/scf_processed.dta")

scf_data["retired"] = scf_data["age"] >= 71

# %%
scf_data["age"].unique()
# Out:
# array([35, 40, 51, 28, 32, 33, 52, 62, 63, 21, 27, 43, 30, 23, 56, 70, 50,
#        75, 44, 55, 22, 64, 38, 41, 20, 69, 89, 31, 47, 59, 71, 77, 68, 49,
#        57, 25, 36, 34, 65, 79, 60, 73, 26, 48, 54, 80, 37, 67, 46, 42, 61,
#        45, 39, 58, 78, 76, 81, 29, 82, 72, 66, 24, 85, 19, 53, 74, 83, 18,
#        84, 87, 90, 86, 88, 91, 95, 92, 93, 94, 17], dtype=int8)

# %%
def weighted_mean(data, var, weights):
    stats = DescrStatsW(data[var], weights=data[weights])
    return stats.mean


def to_percent(y, position):
    return f"{100 * y:.2f}%"


formatter = FuncFormatter(to_percent)

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres1", "wgt"
).unstack().plot()
plt.title("Reason for saving: can't save")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/1201100060.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres2", "wgt"
).unstack().plot()
plt.title("Reason for saving: education")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/2384399675.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres3", "wgt"
).unstack().plot()
plt.title("Reason for saving: family")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/2346591443.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres4", "wgt"
).unstack().plot()
plt.title("Reason for saving: home")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/173237029.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres5", "wgt"
).unstack().plot()
plt.title("Reason for saving: purchases")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/3279881744.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres6", "wgt"
).unstack().plot()
plt.title("Reason for saving: retirement")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/2315203495.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres7", "wgt"
).unstack().plot()
plt.title("Reason for saving: liquidity/the future")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/992497806.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres8", "wgt"
).unstack().plot()
plt.title("Reason for saving: investment")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/2742888852.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["year", "edcl_lbl"]).apply(
    weighted_mean, "savres9", "wgt"
).unstack().plot()
plt.title("Reason for saving: no particular reason")
plt.gca().yaxis.set_major_formatter(formatter)
# Out:
# /tmp/ipykernel_3544/3958459272.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["year", "edcl_lbl"]).apply(

# %%
scf_data.groupby(["edcl_lbl", "retired"]).apply(
    weighted_mean, "savres3", "wgt"
)  # family
# Out:
# /tmp/ipykernel_3544/902805575.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl", "retired"]).apply(
# edcl_lbl                       retired
# Bachelors degree or higher     False      0.033786
#                                True       0.058411
# high school diploma or GED     False      0.053497
#                                True       0.079938
# no high school diploma/GED     False      0.072402
#                                True       0.053860
# some college or Assoc. degree  False      0.045830
#                                True       0.066180
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres6", "wgt")  # retirement
# Out:
# /tmp/ipykernel_3544/3313085655.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres6", "wgt")  # retirement
# edcl_lbl
# Bachelors degree or higher       0.375299
# high school diploma or GED       0.256231
# no high school diploma/GED       0.179858
# some college or Assoc. degree    0.277846
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres7", "wgt")  # the future
# Out:
# /tmp/ipykernel_3544/921483200.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres7", "wgt")  # the future
# edcl_lbl
# Bachelors degree or higher       0.338060
# high school diploma or GED       0.350402
# no high school diploma/GED       0.336672
# some college or Assoc. degree    0.359677
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres5", "wgt")  # purchases
# Out:
# /tmp/ipykernel_3544/976294478.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres5", "wgt")  # purchases
# edcl_lbl
# Bachelors degree or higher       0.069803
# high school diploma or GED       0.118682
# no high school diploma/GED       0.150370
# some college or Assoc. degree    0.106968
# dtype: float64

# %%
scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres1", "wgt")  # can't save
# Out:
# /tmp/ipykernel_3544/2717839900.py:1: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   scf_data.groupby(["edcl_lbl"]).apply(weighted_mean, "savres1", "wgt")  # can't save
# edcl_lbl
# Bachelors degree or higher       0.020601
# high school diploma or GED       0.052192
# no high school diploma/GED       0.105367
# some college or Assoc. degree    0.036308
# dtype: float64

# %%
all_reasons = []

reasons = [
    "Can't save",
    "Education",
    "Family",
    "Home",
    "Purchases",
    "Retirement",
    "Liquidity/the future",
    "Investment",
    "No particular reason",
]

for i in range(1, 10):
    temp = (
        scf_data.groupby(
            [
                "edcl_lbl",
            ]
        )
        .apply(weighted_mean, f"savres{i}", "wgt")
        .reset_index()
    )
    temp["Reasons for Saving"] = reasons[i - 1]
    all_reasons.append(temp)

all_reasons = pd.concat(all_reasons)
pivot = all_reasons.pivot_table(
    index=[
        "edcl_lbl",
    ],
    columns="Reasons for Saving",
    values=0,
)
# Out:
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")

# %%
# New code to format as percentages
pivot = pivot.applymap(lambda x: f"{x:.2%}")

pivot
# Out:
# /tmp/ipykernel_3544/4261576845.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pivot = pivot.applymap(lambda x: f"{x:.2%}")
# Reasons for Saving            Can't save Education Family   Home Investment  \
# edcl_lbl
# Bachelors degree or higher         2.06%     8.86%  3.67%  3.63%      2.35%
# high school diploma or GED         5.22%     7.98%  5.75%  4.79%      2.64%
# no high school diploma/GED        10.54%     7.35%  6.73%  4.42%      3.01%
# some college or Assoc. degree      3.63%     8.79%  4.82%  4.58%      2.61%
#
# Reasons for Saving            Liquidity/the future No particular reason  \
# edcl_lbl
# Bachelors degree or higher                  33.81%                1.11%
# high school diploma or GED                  35.04%                1.09%
# no high school diploma/GED                  33.67%                1.26%
# some college or Assoc. degree               35.97%                1.12%
#
# Reasons for Saving            Purchases Retirement
# edcl_lbl
# Bachelors degree or higher        6.98%     37.53%
# high school diploma or GED       11.87%     25.62%
# no high school diploma/GED       15.04%     17.99%
# some college or Assoc. degree    10.70%     27.78%

# %%
pivot.to_html("table1.tex")

# %%
scf_data = scf_data[scf_data["retired"] == True]

# %%
all_reasons = []

reasons = [
    "Can't save",
    "Education",
    "Family",
    "Home",
    "Purchases",
    "Retirement",
    "Liquidity/the future",
    "Investment",
    "No particular reason",
]

for i in range(1, 10):
    temp = (
        scf_data.groupby(
            [
                "edcl_lbl",
            ]
        )
        .apply(weighted_mean, f"savres{i}", "wgt")
        .reset_index()
    )
    temp["Reasons for Saving"] = reasons[i - 1]
    all_reasons.append(temp)

all_reasons = pd.concat(all_reasons)
pivot = all_reasons.pivot_table(
    index=[
        "edcl_lbl",
    ],
    columns="Reasons for Saving",
    values=0,
)
# Out:
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")
# /tmp/ipykernel_3544/4287443728.py:22: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(weighted_mean, f"savres{i}", "wgt")

# %%
# New code to format as percentages
pivot = pivot.applymap(lambda x: f"{x:.2%}")

pivot
# Out:
# /tmp/ipykernel_3544/4261576845.py:2: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   pivot = pivot.applymap(lambda x: f"{x:.2%}")
# Reasons for Saving            Can't save Education Family   Home Investment  \
# edcl_lbl
# Bachelors degree or higher         5.36%     1.88%  5.84%  0.55%      1.64%
# high school diploma or GED         6.84%     1.11%  7.99%  0.24%      2.32%
# no high school diploma/GED        13.65%     0.73%  5.39%  0.53%      2.04%
# some college or Assoc. degree      6.79%     1.45%  6.62%  0.45%      2.35%
#
# Reasons for Saving            Liquidity/the future No particular reason  \
# edcl_lbl
# Bachelors degree or higher                  42.19%                3.06%
# high school diploma or GED                  41.62%                3.38%
# no high school diploma/GED                  40.02%                2.39%
# some college or Assoc. degree               43.21%                2.86%
#
# Reasons for Saving            Purchases Retirement
# edcl_lbl
# Bachelors degree or higher       12.79%     26.68%
# high school diploma or GED       14.39%     22.09%
# no high school diploma/GED       16.52%     18.74%
# some college or Assoc. degree    14.88%     21.41%

# %%
pivot.to_html("table2.tex")
